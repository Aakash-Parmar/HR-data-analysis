# %% [markdown]
# # Prediction if an employee will leave the company or not

# %% [markdown]
# Importing necessary libraries for EDA

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Reading the csv file which contains the data of employees and various features

# %%
df=pd.read_csv('HR_comma_sep.csv')
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
df_left=df[df.left==1]

# %%
df_left.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
y=df['left']
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: left, dtype: int64

# %% [markdown]
# Checking if we have any null values in the data, and whether the data is balanced or imbalanced

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.0+ MB

# %% [markdown]
# ## Plotting a graph to see does an employee leave on the basis of satisfaction level,department,working hours,projects,evaluation

# %%
sns.countplot(x='left',data=df)
# Out:
# <AxesSubplot:xlabel='left', ylabel='count'>

# %% [markdown]
# Above graph gives you an idea of how many employees have left

# %%
sns.relplot(x=df['satisfaction_level'],y=df['left'], data=df)

# %% [markdown]
# As you can see nothing can be said about the above graph.

# %% [markdown]
# #### Trying different method to visualise this data:

# %%
plt.figure(figsize=(18,5))
sns.countplot(x=df['satisfaction_level'], data=df,hue='left')
# Out:
# <AxesSubplot:xlabel='satisfaction_level', ylabel='count'>

# %%
plt.figure(figsize=(18,5))
plt.title('No. of employees left VS satisfaction level')
sns.countplot(x=df_left['satisfaction_level'], data=df_left)
# Out:
# <AxesSubplot:title={'center':'No. of employees left VS satisfaction level'}, xlabel='satisfaction_level', ylabel='count'>

# %% [markdown]
# From the above graph we can say employees having low satisfaction level have higher count of leaving

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=df['left'], data=df,hue='Department')
# Out:
# <AxesSubplot:xlabel='left', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
plt.title('No. of employees left from different Departments')
sns.countplot(x=df_left['left'], data=df_left,hue='Department')
# Out:
# <AxesSubplot:title={'center':'No. of employees left from different Departments'}, xlabel='left', ylabel='count'>

# %%
pd.crosstab(df.Department,df.left).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Department'>

# %% [markdown]
# Majority people left from sales and technical department but most of the employees were working in these department in the first place so the graph doesn't really give some strong information

# %%
plt.figure(figsize=(18,5))
sns.countplot(x=df['average_montly_hours'], data=df,hue='left')
# Out:
# <AxesSubplot:xlabel='average_montly_hours', ylabel='count'>

# %%
plt.figure(figsize=(18,5))
sns.countplot(x=df_left['average_montly_hours'], data=df_left)
# Out:
# <AxesSubplot:xlabel='average_montly_hours', ylabel='count'>

# %%
plt.figure(figsize=(18,5))
sns.countplot(x=df['last_evaluation'], data=df,hue='left')
# Out:
# <AxesSubplot:xlabel='last_evaluation', ylabel='count'>

# %%
plt.figure(figsize=(18,5))
sns.countplot(x=df_left['last_evaluation'], data=df_left)
# Out:
# <AxesSubplot:xlabel='last_evaluation', ylabel='count'>

# %%
sns.countplot(x=df['promotion_last_5years'], data=df,hue='left')
# Out:
# <AxesSubplot:xlabel='promotion_last_5years', ylabel='count'>

# %%
sns.countplot(x=df['time_spend_company'], data=df,hue='left')
# Out:
# <AxesSubplot:xlabel='time_spend_company', ylabel='count'>

# %%
sns.countplot(x=df_left['time_spend_company'], data=df_left)
# Out:
# <AxesSubplot:xlabel='time_spend_company', ylabel='count'>

# %%
sns.countplot(x=df['Work_accident'], data=df,hue='left')
# Out:
# <AxesSubplot:xlabel='Work_accident', ylabel='count'>

# %%
sns.countplot(x=df['number_project'], data=df,hue='left')
# Out:
# <AxesSubplot:xlabel='number_project', ylabel='count'>

# %% [markdown]
# #### Now trying to differentiate employees on the basis of their salary
#
# Now here we can observe that the employees which have less salary are more tend to leave the firm as compared to medium and high salary getting employees

# %%
sns.relplot(x=df['satisfaction_level'],y=df['left'], data=df,hue='salary')

# %%
sns.relplot(x=df['satisfaction_level'],y=df['left'], data=df,hue='salary',size='salary')

# %%
sns.countplot(x=df['left'], data=df,hue='salary')
# Out:
# <AxesSubplot:xlabel='left', ylabel='count'>

# %% [markdown]
# ### From the data analysis so far we can conclude that we will use following variables as independant variables in our model
#
# *1. Satisfaction Level*
#
# *2. Average Monthly Hours*
#
# *3. Promotion Last 5 Years*
#
# *4. Salary*

# %%
df.drop(['last_evaluation','average_montly_hours','time_spend_company','Work_accident','left','Department'],inplace=True,axis=1)

# %%
df.head()
# Out:
#    satisfaction_level  number_project  promotion_last_5years  salary
# 0                0.38               2                      0     low
# 1                0.80               5                      0  medium
# 2                0.11               7                      0  medium
# 3                0.72               5                      0     low
# 4                0.37               2                      0     low

# %% [markdown]
# ## Encoding

# %%
x=pd.get_dummies(df['salary'])

# %%
x.drop(['high'],axis=1,inplace=True)
x.head()
# Out:
#    low  medium
# 0    1       0
# 1    0       1
# 2    0       1
# 3    1       0
# 4    1       0

# %%
df.drop(['salary'],axis=1,inplace=True)

# %%
X=pd.concat([df,x],axis=1)

# %%
X.head()
# Out:
#    satisfaction_level  number_project  promotion_last_5years  low  medium
# 0                0.38               2                      0    1       0
# 1                0.80               5                      0    0       1
# 2                0.11               7                      0    0       1
# 3                0.72               5                      0    1       0
# 4                0.37               2                      0    1       0

# %% [markdown]
# ## Splitting the data for training and testing

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
pred=lr.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(pred,y_test)
# Out:
# 0.794

# %%
lr.score(X_test,y_test)
# Out:
# 0.794
